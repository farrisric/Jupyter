# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.loadtxt("/home/riccardo/Mixtures/rdf_mixtures.txt", usecols = (1,2,3,4,5,6,7,8,9))


fig1 = plt.plot(x[0,:], x[2,:], "b-", label = "1BO D--A" )
fig1 = plt.plot(x[0,:], x[4,:], "b--", label = "1BO H--A")
fig1 = plt.plot(x[0,:], x[6,:], "r-", label = "2BO D--A")
fig1 = plt.plot(x[0,:], x[8,:], "r--", label = "2BO H--A")
fig1 = plt.legend()
plt.xlim(0,1)
fig1 = plt.title("Coordination Number for different mixtures")
fig1 = plt.xlabel("x$_{DBE}$")
fig1 = plt.ylabel("Coordination Number of D-A and H-A")

plt.savefig('/home/riccardo/Mixtures/Figures/nc.svg', format='svg', dpi=1200)

# %%
 #for i in range(2,9,2):
fig1 = plt.plot(x[0,:], x[1,:], "b-", label = "1BO D-A" )
fig1 = plt.plot(x[0,:], x[3,:], "b--", label = "1BO H-A")
fig1 = plt.plot(x[0,:], x[5,:], "r-", label = "2BO D-A")
fig1 = plt.plot(x[0,:], x[7,:], "r--", label = "2BO H-A")
fig1 = plt.legend()
fig1 = plt.title("RDF first minimum of Donor Acceptor and Hydrongen Acceptor")
fig1 = plt.xlabel("x$_{DBE}$")
fig1 = plt.ylabel("RDF first minimum of D-A and H-A ($\AA$)")
plt.xlim(0,1)
plt.savefig('/home/riccardo/Mixtures/Figures/Sims/rdf.svg', format='svg', dpi=1200)

# %%
np.delete(x[9,:],0)

fig1 = plt.plot(np.delete(x[0,:],0.00), np.delete(x[9,:],0), "b-", label = "1BO Oa-Oe" )
fig1 = plt.plot(np.delete(x[0,:],0.00), np.delete(x[10,:],0), "b--", label = "1BO CoordNum")
fig1 = plt.plot(np.delete(x[0,:],0.00), np.delete(x[11,:],0), "r-", label = "2BO Oa-Oe")
fig1 = plt.plot(np.delete(x[0,:],0.00), np.delete(x[12,:],0), "r--", label = "2BO CoordNum")
fig1 = plt.legend()
fig1 = plt.title("RDF first minimum of O Alcool and O Ether")
fig1 = plt.xlabel("x$_{DBE}$")
fig1 = plt.ylabel("RDF first minimum of Oa-Oe ($\AA$)")
plt.xlim(0,1)
plt.savefig('/home/riccardo/Mixtures/Figures/rdf_OaOe.svg', format='svg', dpi=1200)
# Out:
# /home/riccardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/riccardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   after removing the cwd from sys.path.
# /home/riccardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   """
# /home/riccardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future

# %%
#1bovsdbe
vb = np.array([0,0.0566,0.0917,0.1477,0.2016,0.3042,0.4014,0.4505,0.4956,0.6187,0.7165,0.8005,0.8962,0.9502,1])
vc = np.array([0,-0.069,-0.105,-0.149,-0.185,-0.228,-0.241,-0.246,-0.247,-0.232,-0.208,-0.176,-0.119,-0.071,0,])
#1bo_sims
vb_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
vc_sims = np.array([0,-0.047008080777971,-0.086644923621691,-0.095503418062201,-0.093939546182881,-0.061771840642251,-0.038916231991372,-0.03826752533511,-0.003235157973264,0])

#2bovsdbe
vx = np.array([0,0.0267,0.0463,0.0596,0.1028,0.1424,0.1951,0.2512,0.2979,0.4077,0.5059,0.5572,0.63,0.7137,0.7984,0.8406,0.9039,0.9571,1])
vy = np.array([0,-0.016,-0.008,0.003,0.012,0.023,0.041,0.062,0.079,0.105,0.118,0.124,0.121,0.103,0.081,0.061,0.036,0.022,0])
#2bo_sims
vx_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
vy_sims = np.array([0,0.080369980824727,0.155964233139287,0.20208110519809,0.223703081621032,0.22751356200552,0.241479165953191,0.148582686536015,0.117098370117472,0])
plt.plot((vx-1)*-1,vy, "b-", label = "2BO exp")
plt.plot(vx_sims,vy_sims, "b^", label = "2BO sims")
plt.plot((vb-1)*-1,vc, "r-", label = "1BO exp")
plt.plot(vb_sims,vc_sims,"rv", label = "1BO sims")

plt.axhline(linewidth=1, color = "black")
plt.xlim(0,1)

plt.xlabel("x$_{DBE}$")
plt.ylabel("V$^E$  ( m$^3$$\cdot$ mol$^{-1}$)")
plt.title("Excess Molar Volume of 1BO and 2BO in DBE")
plt.legend()

plt.savefig('/home/riccardo/Mixtures/Figures/Sims/ex_vol.svg', format='svg', dpi=1200)

# %%
#1bovsdbe
eb = np.array([0,0.0547,0.0717,0.1038,0.1338,0.1564,0.1881,0.236,0.2579,0.3166,0.3819,0.41,0.481,0.5527,0.6495,0.7119,0.7875,0.8476,0.8811,0.9175,0.9368,1])
ec = np.array([0,386,470,598,686,752,805,886,895,946,945,937,910,841,711,613,471,346,273,196,150,0])
#1bo_sims
eb_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
ec_sims = np.array([0,169.187885,295.803570000002,442.627975000001,546.043380000002,601.342785,605.178990000003,509.543419199998,410.730309599997,0
])
#2bovsdbe    
ex = np.array([0,0.0545,0.0714,0.1034,0.1333,0.1558,0.1874,0.2352,0.2571,0.3157,0.3809,0.409,0.4799,0.5516,0.6486,0.711,0.7868,0.847,0.8807,0.9172,0.9366,1])
ey = np.array([0,468,580,749,869,920,999,1120,1134,1236,1267,1253,1255,1177,1054,910,728,551,436,313,238,0])
#2bo_sims
ex_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
ey_sims = np.array([0,499.490627,889.223427999994,1156.392225,1293.51498,1292.84815499999,1193.29249,859.120803200009,589.127701599987,0])


plt.plot((eb-1)*-1,ec, "b-", label = "1BO exp")
plt.plot(eb_sims,ec_sims,"b^", label = "1BO sim")
plt.plot((ex-1)*-1,ey, "r-", label = "2BO exp")
plt.plot(ex_sims,ey_sims,"rv", label = "2BO sim")
plt.xlim(0,1)
plt.ylim(0,1400)
plt.legend()

plt.xlabel("x$_{DBE}$")
plt.ylabel("H$^E$ ( j $\cdot$ mol$^{-1}$)")
plt.title("Excess Molar Enthalpie of 1BO and 2BO in DBE")

plt.savefig('/home/riccardo/Mixtures/Figures/Sims/ex_ent.svg', format='svg', dpi=1200)

# %%
hbond_num_1bo = np.array([0.77185,0.756174,0.745542, 0.72953,0.711368, 0.664622,0.621696,0.503874,0.334232])
hbond_num_2bo = np.array([ 1,0.708603,0.682741, 0.647667,0.612727, 0.56421,0.495406,0.358212,0.20157])
hbond_num_1bo35 = np.array([0.76697,0.751587,0.741149, 0.725369,0.707392, 0.660854,0.618177,0.501102,0.332318]) 
plt.plot(x[0,:],hbond_num_1bo, "b-", label = "1BO3.7")
plt.plot(x[0,:],hbond_num_1bo35, "b--", label = "1BO3.5")
plt.plot(x[0,:],hbond_num_2bo, "r-", label = "2BO3.7")
plt.xlim(0,1)
plt.legend()
plt.xlabel("x$_{DBE}$")
plt.ylabel("Hydrogen bond Al-Al per molecule")
plt.title("Hydrogen bond per molecule")

plt.savefig('/home/riccardo/Mixtures/Figures/HB/hb_per_mol.svg', format='svg', dpi=1200)

# %%
#1bovsdbe
vb = np.array([0,0.0566,0.0917,0.1477,0.2016,0.3042,0.4014,0.4505,0.4956,0.6187,0.7165,0.8005,0.8962,0.9502,1])
vc = np.array([0,-0.069,-0.105,-0.149,-0.185,-0.228,-0.241,-0.246,-0.247,-0.232,-0.208,-0.176,-0.119,-0.071,0,])
#1bo_sims
vb_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
vc_sims = np.array([0,-0.047008080777971,-0.086644923621691,-0.095503418062201,-0.093939546182881,-0.061771840642251,-0.038916231991372,-0.03826752533511,-0.003235157973264,0])

#2bovsdbe
vx = np.array([0,0.0267,0.0463,0.0596,0.1028,0.1424,0.1951,0.2512,0.2979,0.4077,0.5059,0.5572,0.63,0.7137,0.7984,0.8406,0.9039,0.9571,1])
vy = np.array([0,-0.016,-0.008,0.003,0.012,0.023,0.041,0.062,0.079,0.105,0.118,0.124,0.121,0.103,0.081,0.061,0.036,0.022,0])
#2bo_sims
vx_sims = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
vy_sims = np.array([0,0.080369980824727,0.155964233139287,0.20208110519809,0.223703081621032,0.22751356200552,0.241479165953191,0.148582686536015,0.117098370117472,0])
porco2bo = np.array([12.66, 14.002857142857144, 16.05, 18.288, 20.009999999999998, 19.43333333333333, 18.61, 12.25, 6.125,0])
dio1bo =  np.array([4.8275, 6.142857142857142, 7.216666666666667, 8.692, 10.91, 12.686666666666667, 15.89, 13.3125, 8.708333333333334,0])   

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax2.plot(vb_sims,porco2bo, "b--", label = "2bo perc")
ax2.plot(vb_sims,dio1bo, "r--", label = "1bo perc")


ax1.plot((vx-1)*-1,vy, "b-", label = "2bo exp")
ax1.plot(vx_sims,vy_sims, "b^", label = "2bo sims")
ax1.plot((vb-1)*-1,vc, "r-", label = "1bo exp")
ax1.plot(vb_sims,vc_sims,"rv", label = "1bo sims")

plt.axhline(linewidth=1, color = "black")
plt.xlim(0,1)
plt.ylim(-25,25)
plt.xlabel("Molar Fraction of DBE")
plt.title("Excess Molar Volume of 1BO and 2BO in DBE")
plt.legend()

plt.savefig('/home/riccardo/Mixtures/Figures/porcodio.svg', format='svg', dpi=1200)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
rings = "analysis/tot_rings.dat"
clusters = "Clusters/plottami.dat"

for alcool in ["2BO"]:
    path = f"E:/Mixtures/Jobs/{alcool}"
    dic1 = [x for x in os.listdir(path)]

    dic2 = {}
    for value in dic1:
        with open(f"{path}/{value}/{clusters}", "r") as rg:
                items = rg.read().splitlines()
                items = list(map(int,items))
        dic2[value] = items

    rings_to_count = {x:[] for x in range(1,401)}    
     

    for mix in sorted (dic2.keys()):
   
        for n,r in rings_to_count.items():
            n_mol = 400-400*float(mix)
            counter = dic2[mix].count(n)/n_mol*n
            #print(f"We have {counter}% molecules in {n} m-rings on the mixture {mix}DBE")
            rings_to_count[n].append(counter)
    
    big_clust = np.zeros(9)
    for x in range(7,401):
        big_clust = big_clust + np.array(list(rings_to_count[x]))
    
    little_clust = np.zeros(9)
    for x in range(1,7):
        little_clust = little_clust + np.array(list(rings_to_count[x]))
    
    xax = np.array([0.00,0.125,0.25,0.375,0.50,0.625,0.75,0.88,0.94])
    for x in rings_to_count.keys():
        if x < 7:
            plt.plot(xax,rings_to_count[x], label = f"{x}m-cluster")
    plt.plot(xax,big_clust, label = ">6m-cluster", linewidth=3)
    plt.plot(xax,little_clust, label = "<6m-cluster", linewidth=3)
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.01),ncol=3, fancybox=True, shadow=True)    
    plt.xlim(0,1)
    plt.ylim(0,100)
        
    plt.title(f"Fraction of {alcool} Molecules in Different Clusters")
    plt.xlabel("x$_{DBE}$")
    plt.ylabel(f"{alcool} molecules in Clusters (%)")
    #plt.savefig(f"/home/riccardo/Mixtures/Figures/Clust_An/{alcool}_faction_Clusters.svg", format='svg', dpi=1200)

# %%
big_ring = np.zeros(9)
for x in range(3,7):
    big_ring = big_ring + np.array(list(rings_to_count[x]))
print(big_ring)
# Out:
# [ 4.8275      6.14285714  7.21666667  8.692      10.91       12.68666667
#  15.89       13.3125      8.70833333]

# %%
rsbo_sum = np.array([12.66   ,    14.00285714 ,16.05   ,    18.288    ,  20.01    ,   19.43333333,
 18.61  ,     12.25     ,   6.125     ])
onebo_sum = np.array([ 4.8275 ,     6.14285714 , 7.21666667 , 8.692  ,    10.91  ,     12.68666667,
 15.89    ,   13.3125   ,   8.70833333])

plt.plot(xax,rsbo_sum, "b--", label = "2bo")
plt.plot(xax,onebo_sum, "r-" ,label = "1bo")
plt.axvline(0.75, 0, 1, color = "blue" ,label='2BO x$_{DBE}$ max V$^E$')
plt.axvline(0.375, 0, 1, color = "red" ,label='1BO x$_{DBE}$ min V$^E$')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.01),ncol=2, fancybox=True, shadow=True)  
plt.ylabel("molecules in 3-6m Rings (%)")
plt.xlabel("x$_{DBE}$")
plt.ylim(0,27)
plt.xlim(0,1)
plt.savefig(f"/home/riccardo/Mixtures/test.svg", format='svg', dpi=1200)
