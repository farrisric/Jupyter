# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0.00, 0.125, 0.25, 0.375, 0.50, 0.625, 0.75, 0.88, 0.94])
hbond_num_1bo = np.array([1.533925,1.505428571,1.481626667,1.455544,1.40401,1.34528,1.22755,1.053583333,0.704124167])
hbond_num_2bo = np.array([ 1.47545,1.424228571,1.371013333,1.298248,1.2321,1.143124,0.99959,0.701608333,0.407553333])

hbond_et_num_1bo = np.array([0,0.016901543,0.035152667,0.0544932,0.07877,0.103742667,0.154085,0.24224375,0.373225,])
hbond_et_num_2bo = np.array([0,0.022205657,0.043868333,0.0663028,0.0896325,0.120468,0.161156,0.243564583,0.320385417])


plt.plot(x,hbond_num_1bo, "b-o", linewidth=2,  label = "1BO-1BO")
plt.plot(x,hbond_et_num_1bo, "b--o",linewidth=2, label = "1BO-DBE")
plt.plot(x,hbond_num_2bo, "r-o",linewidth=2, label = "2BO-2BO")

plt.plot(x,hbond_et_num_2bo, "r--o",linewidth=2, label = "2BO-DBE")

plt.xlim(0,1)
plt.ylim(0,2)
plt.legend()
plt.xlabel("${x_{DBE}}$", fontsize=14)
plt.ylabel("${n_a}$", fontsize=14)
#plt.title("Hydrogen bond per molecule")

plt.savefig('C:/Users/r.farris10/Dropbox/Mixtures_2019/TesiFinaleChePunisceIDisonesti/fig/plot/hbond.png', format='png', dpi=800)

# %%
x = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])
one_bo_ent = np.array([0,141.395665,299.19261,449.217775,568.80434,587.556505,625.97347,500.1235616,380.3410808,0])
two_bo_ent = np.array([0,484.69025,848.8813,1115.79435,1260.43,1324.15755,1154.9409,854.117576,569.262488,0])

one_bo_ent_exp_x = np.array([0,0.0547,0.0717,0.1038,0.1338,0.1564,0.1881,0.236,0.2579,0.3166,0.3819,0.41,0.481,0.5527,0.6495,0.7119,0.7875,0.8476,0.8811,0.9175,0.9368,1])
one_bo_ent_exp_y= np.array([0,386,470,598,686,752,805,886,895,946,945,937,910,841,711,613,471,346,273,196,150,0])
two_bo_ent_exp_x = np.array([0,0.0545,0.0714,0.1034,0.1333,0.1558,0.1874,0.2352,0.2571,0.3157,0.3809,0.409,0.4799,0.5516,0.6486,0.711,0.7868,0.847,0.8807,0.9172,0.9366,1])
two_bo_ent_exp_y = np.array([0,468,580,749,869,920,999,1120,1134,1236,1267,1253,1255,1177,1054,910,728,551,436,313,238,0])

err1bo = np.array([0,10,10,9,10,10,10,11,10,0])

plt.plot(1-one_bo_ent_exp_x,one_bo_ent_exp_y, "b-", linewidth = 2, label = "1BO + DBE")
#plt.plot(x,one_bo_ent, "bo", linewidth = 2, label = "1BO sims")
plt.plot(1-two_bo_ent_exp_x,two_bo_ent_exp_y ,"r-", linewidth = 2, label = "2BO + DBE")
#plt.plot(x,two_bo_ent, "ro", linewidth = 2, label = "2BO sims")




plt.xlabel("x$_{DBE}$", fontsize = 14)
plt.ylabel("H$^E$ ( J $\cdot$ mol$^{-1}$)", fontsize = 14)

plt.legend()

plt.xlim(0,1)
plt.ylim(0,)
plt.savefig('C:/Users/r.farris10/Dropbox/Mixtures_2019/PresentazioneFinaleChePunisceIDisonesti/fig/plot/entalpie_exp.png', format='png', dpi=800)

# %%
import numpy as np
import matplotlib.pyplot as plt
#1bovsdbe
vb = np.array([0,0.0566,0.0917,0.1477,0.2016,0.3042,0.4014,0.4505,0.4956,0.6187,0.7165,0.8005,0.8962,0.9502,1])
vc = np.array([0,-0.069,-0.105,-0.149,-0.185,-0.228,-0.241,-0.246,-0.247,-0.232,-0.208,-0.176,-0.119,-0.071,0,])

x = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94,1])

vx = np.array([0,0.0267,0.0463,0.0596,0.1028,0.1424,0.1951,0.2512,0.2979,0.4077,0.5059,0.5572,0.63,0.7137,0.7984,0.8406,0.9039,0.9571,1])
vy = np.array([0,-0.016,-0.008,0.003,0.012,0.023,0.041,0.062,0.079,0.105,0.118,0.124,0.121,0.103,0.081,0.061,0.036,0.022,0])

vol1bo = np.array([0.00,-0.07,-0.11,-0.09,-0.08,-0.08,-0.06,-0.03,-0.03,0.00])
err_vol1bo = np.array([0.00,0.01,0.01,0.01,0.01,0.01,0.02,0.02,0.02,0.00])

vol2bo = np.array([0.00,0.06,0.11,0.19,0.21,0.28,0.20,0.15,0.10,0.00])
err_vol2bo = np.array([0.00,0.01,0.01,0.01,0.01,0.01,0.02,0.02,0.02,0.00])

plt.plot(vb,vc, "b-", linewidth = 2, label = "1BO + DBE")
#plt.errorbar(x, vol1bo, yerr = err_vol1bo, fmt = "bo", label = "1BO sims")

plt.plot(vx,vy, "r-", linewidth = 2, label = "2BO + DBE")
#plt.errorbar(x,vol2bo,yerr = err_vol2bo, fmt = "ro", label = "2BO sims")

plt.axhline(linewidth=1, color = "black")
plt.legend(loc = "upper left")

plt.xlabel("x$_{DBE}$", fontsize = 14)
plt.ylabel("V$^E$  ( cm$^3$$\cdot$ mol$^{-1}$)", fontsize = 14)
plt.xlim(0,1)
plt.savefig('C:/Users/r.farris10/Dropbox/Mixtures_2019/PresentazioneFinaleChePunisceIDisonesti/fig/plot/volumi_exp.png', format='png', dpi = 800)

# %%
import matplotlib.pyplot as plt
import numpy as np

c_num_1boOaOa = np.array([2.00,1.971301,1.918765,1.861857,1.792266,1.707437,1.559753,1.287375,0.875075])
c_num_2boOaOa = np.array([1.93742,1.88048,1.807721,1.728973,1.63991,1.528381,1.350565,0.942449,0.543157])
c_num_1boOaOe = np.array([0,0.022011,
0.044765,
0.070026,
0.101352,
0.13662,
0.199024,
0.319728,
0.488954
])
c_num_2boOaOe = np.array([0,0.029906,
0.058226,
0.088758,
0.117947,
0.15913,
0.215333,
0.324119,
0.437793,

])
x = np.array([0,0.125,0.25,0.375,0.5,0.625,0.75,0.88,0.94])
plt.plot(x,c_num_1boOaOe+c_num_1boOaOa, "ko-", label = "1BO tot")
plt.plot(x,c_num_2boOaOe+c_num_2boOaOa, "ko--", label = "2BO tot")
plt.plot(x,c_num_1boOaOa, "bo-", label = "1BO-1BO")
plt.plot(x,c_num_1boOaOe, "bo--", label = "1BO-DBE")
plt.plot(x,c_num_2boOaOa, "ro-", label = "2BO-2BO")

plt.plot(x,c_num_2boOaOe, "ro--", label = "2BO-DBE")



plt.rcParams['lines.linewidth'] = 2
SMALL_SIZE = 8
MEDIUM_SIZE = 12

plt.legend(loc = "center left")
#plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.16),ncol=3, fancybox=True, shadow=True) 
plt.xlim(0,1)
plt.ylim(0,2)
#fig1 = plt.title("Coordination Number for different mixtures")
fig1 = plt.xlabel("x$_{DBE}$",fontsize = 14)
fig1 = plt.ylabel("Coordination Number",fontsize = 14)

plt.savefig('C:/Users/r.farris10/Dropbox/Mixtures_2019/TesiFinaleChePunisceIDisonesti/fig/plot/numcoord.png', format='png', dpi=800)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0.00, 0.125, 0.25, 0.375, 0.50, 0.625, 0.75, 0.88, 0.94])
hbond_num_1bo = np.array([2.86224,
2.85879,
2.85631,
2.85393,
2.84988,
2.84422,
2.84075,
2.83151,
2.82468,
])
hbond_num_2bo = np.array([ 2.9529,
2.9468,
2.94668,
2.93485,
2.92796,
2.92258,
2.91385,
2.90999,
2.90963
])



plt.plot(x,hbond_num_1bo, "b-o", linewidth=2,  label = "1BO-1BO")
plt.plot(x,hbond_num_2bo, "r-o",linewidth=2, label = "2BO-2BO")


plt.xlim(0,1)
plt.ylim(2.8,3)
plt.legend()
plt.xlabel("${x_{DBE}}$", fontsize=14)
plt.ylabel("$r(O-O) / \AA$", fontsize=14)
#plt.title("Hydrogen bond per molecule")

plt.savefig('C:/Users/r.farris10/Dropbox/Mixtures_2019/TesiFinaleChePunisceIDisonesti/fig/plot/hbond_dist.png', format='png', dpi=800)
